# %% [markdown]
# # Common
# ## Imports

# %%
from platform import python_version

print(python_version())
# Out:
# 3.7.6

# %%
import gym

import hiive.mdptoolbox as mdptoolbox
from hiive.mdptoolbox.mdp import ValueIteration, PolicyIteration, QLearning

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from time import time

# %matplotlib inline

ValueIteration?

# %% [markdown]
# ## Example Code

# %%
env = gym.make('CartPole-v0')
for i_episode in range(20):
    observation = env.reset()
    for t in range(100):
        env.render()
        print(observation)
        action = env.action_space.sample()
        observation, reward, done, info = env.step(action)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            break
env.close()
# Out:
# [-0.03977883 -0.0425485   0.01526147  0.0352031 ]
# [-0.0406298   0.15235131  0.01596553 -0.25262587]
# [-0.03758278  0.34724169  0.01091302 -0.54023051]
# [-3.06379433e-02  1.51968054e-01  1.08407199e-04 -2.44129133e-01]
# [-0.02759858 -0.04315545 -0.00477418  0.04858799]
# [-0.02846169 -0.23820862 -0.00380242  0.3397608 ]
# [-0.03322586 -0.04303277  0.0029928   0.04588124]
# [-0.03408652  0.15204614  0.00391043 -0.24585593]
# [-0.0310456  -0.04313144 -0.00100669  0.04805787]
# [-3.19082248e-02  1.52004931e-01 -4.55361515e-05 -2.44942510e-01]
# [-0.02886813 -0.04311637 -0.00494439  0.04772605]
# [-0.02973045 -0.23816707 -0.00398987  0.33884489]
# [-0.0344938  -0.04298858  0.00278703  0.04490646]
# [-0.03535357  0.1520933   0.00368516 -0.24689583]
# [-0.0323117   0.34716242 -0.00125275 -0.5384141 ]
# [-0.02536845  0.15205811 -0.01202104 -0.24612616]
# [-0.02232729 -0.04289011 -0.01694356  0.04274093]
# [-0.02318509 -0.23776505 -0.01608874  0.33003022]
# [-0.02794039 -0.04241781 -0.00948814  0.0323174 ]
# [-0.02878875 -0.23740242 -0.00884179  0.32199168]
# [-0.0335368  -0.04215568 -0.00240196  0.02653357]
# [-0.03437991 -0.23724311 -0.00187128  0.31845768]
# [-0.03912477 -0.04209455  0.00449787  0.02518521]
# [-0.03996666 -0.23728072  0.00500157  0.31928386]
# [-0.04471228 -0.43247354  0.01138725  0.61353989]
# [-0.05336175 -0.62775276  0.02365805  0.9097875 ]
# [-0.06591681 -0.82318677  0.0418538   1.2098113 ]
# [-0.08238054 -1.01882345  0.06605002  1.51531076]
# [-0.10275701 -0.82456007  0.09635624  1.24395567]
# [-0.11924821 -1.02077724  0.12123535  1.56520106]
# [-0.13966376 -1.21712171  0.15253937  1.89311196]
# [-0.16400619 -1.41353443  0.19040161  2.22898289]
# Episode finished after 32 timesteps
# [ 0.03879538 -0.02296497 -0.03939767 -0.01969714]
# [ 0.03833608  0.17269919 -0.03979161 -0.32454555]
# [ 0.04179006  0.36836446 -0.04628252 -0.62950678]
# [ 0.04915735  0.56410068 -0.05887266 -0.93639891]
# [ 0.06043937  0.75996505 -0.07760064 -1.24698503]
# [ 0.07563867  0.95599164 -0.10254034 -1.56293172]
# [ 0.0947585   0.76223459 -0.13379897 -1.3039168 ]
# [ 0.11000319  0.9587754  -0.15987731 -1.6353127 ]
# [ 0.1291787   0.76584986 -0.19258356 -1.39641897]
# Episode finished after 9 timesteps
# [ 0.02250845 -0.02636854 -0.01416675 -0.01241182]
# [ 0.00718113 -0.16565523 -0.02054647  0.28612811]
# [ 0.00386802  0.02975363 -0.01482391 -0.01296355]
# [ 0.00446309 -0.16515262 -0.01508318  0.27500564]
# [ 0.00116004 -0.36005616 -0.00958307  0.5628934 ]
# [-0.00604108 -0.55504234  0.0016748   0.85254186]
# [-0.01714193 -0.35994326  0.01872564  0.56038604]
# [-0.02434079 -0.16508906  0.02993336  0.273661  ]
# [-0.02764257 -0.36062504  0.03540658  0.57563267]
# [-0.03485507 -0.16601685  0.04691923  0.2943107 ]
# [-0.03817541 -0.36177523  0.05280544  0.60141431]
# [-0.04541092 -0.55759454  0.06483373  0.91025144]
# [-0.05656281 -0.75353115  0.08303876  1.22258663]
# [-0.07163343 -0.55957131  0.10749049  0.95703473]
# [-0.08282486 -0.3660462   0.12663119  0.69996385]
# [-0.09014578 -0.56267503  0.14063046  1.02967563]
# [-0.10139928 -0.3696759   0.16122398  0.78424413]
# [-0.1087928  -0.56660255  0.17690886  1.12299813]
# [-0.12012485 -0.76354618  0.19936882  1.46554318]
# Episode finished after 27 timesteps
# [ 0.00603266 -0.00105708  0.02913463  0.02270269]
# [ 0.00601151  0.1936352   0.02958868 -0.26064742]
# [ 0.00988422  0.38832255  0.02437573 -0.54385281]
# [ 0.01765067  0.19286668  0.01349868 -0.24359035]
# [ 0.021508    0.38779325  0.00862687 -0.53198508]
# [ 0.02926387  0.58279281 -0.00201283 -0.82193726]
# [ 0.04091972  0.77794224 -0.01845158 -1.11525259]
# [ 0.05647857  0.9733015  -0.04075663 -1.41366605]
# [ 0.0759446   1.16890411 -0.06902995 -1.71880544]
# [ 0.09932268  0.97463783 -0.10340606 -1.44837872]
# [ 0.11881544  0.78092809 -0.13237363 -1.18971342]
# [ 0.134434    0.97749355 -0.1561679  -1.5207864 ]
# [ 0.15398387  0.78456559 -0.18658363 -1.28064316]
# Episode finished after 13 timesteps
# [ 0.00707003  0.04648806 -0.02757506  0.01964489]
# [ 0.00799979  0.2419944  -0.02718216 -0.28160916]
# [ 0.01283968  0.43749332 -0.03281434 -0.58273978]
# [ 0.02158955  0.2428461  -0.04446914 -0.30057181]
# [ 0.02644647  0.43857274 -0.05048057 -0.60694116]
# [ 0.03521792  0.2441916  -0.0626194  -0.33057586]
# [ 0.04010176  0.44014644 -0.06923091 -0.6423301 ]
# [ 0.04890468  0.63616162 -0.08207752 -0.95598617]
# [ 0.06162792  0.83228584 -0.10119724 -1.27328584]
# [ 0.07827363  0.63859017 -0.12666296 -1.01393001]
# [ 0.09104544  0.44536431 -0.14694156 -0.76355254]
# [ 0.09995272  0.64217143 -0.16221261 -1.09862741]
# [ 0.11279615  0.8390133  -0.18418516 -1.43749575]
# Episode finished after 13 timesteps
# [ 0.0365152   0.03530846 -0.02293528  0.00226626]
# [ 0.03722137  0.23075169 -0.02288995 -0.29756388]
# [ 0.0418364   0.03596339 -0.02884123 -0.01218703]
# [ 0.12077619  0.2525028  -0.18472591 -0.75573639]
# [ 0.12582624  0.06034225 -0.19984064 -0.52640059]
# Episode finished after 19 timesteps
# [-0.04459152  0.02756626 -0.04218333 -0.02972522]
# [-0.0440402  -0.16692617 -0.04277784  0.24935567]
# [-0.04737872  0.02877975 -0.03779072 -0.0565075 ]
# [-0.04680313  0.22442261 -0.03892087 -0.36087009]
# [-0.04231468  0.02987489 -0.04613828 -0.08070935]
# [-0.04171718  0.22562683 -0.04775246 -0.38758463]
# [-0.03720464  0.03121409 -0.05550416 -0.11033185]
# [-0.03658036  0.22708565 -0.05771079 -0.41999658]
# [-0.03203865  0.03282688 -0.06611073 -0.14605109]
# [-0.03138211 -0.16128909 -0.06903175  0.1250644 ]
# [-0.03460789  0.03475044 -0.06653046 -0.18857374]
# [-0.03391288  0.23075802 -0.07030193 -0.50148019]
# [-0.02929772  0.42679688 -0.08033154 -0.81546385]
# [-0.02076178  0.23286136 -0.09664081 -0.54909077]
# [-0.01610456  0.42919853 -0.10762263 -0.87059054]
# [-0.00752059  0.62560682 -0.12503444 -1.19507842]
# [ 0.00499155  0.82210594 -0.14893601 -1.52419053]
# [ 0.02143367  1.01867939 -0.17941982 -1.85941194]
# Episode finished after 18 timesteps
# [ 0.02832467 -0.02400418 -0.03705378 -0.02346675]
# [ 0.02784459  0.17162903 -0.03752312 -0.32760645]
# [ 0.03127717  0.36726454 -0.04407525 -0.63188236]
# [ 0.03862246  0.56297281 -0.05671289 -0.9381136 ]
# [ 0.04988192  0.36865947 -0.07547517 -0.66377686]
# [ 0.05725511  0.17466414 -0.0887507  -0.39578092]
# [ 0.06074839  0.37092587 -0.09666632 -0.71507333]
# [ 0.06816691  0.17726548 -0.11096779 -0.45431458]
# [ 0.07171222 -0.01612682 -0.12005408 -0.19856796]
# [ 0.07138968  0.18048942 -0.12402544 -0.52658067]
# [ 0.07499947 -0.01268916 -0.13455705 -0.27540867]
# [ 0.07474569 -0.2056604  -0.14006523 -0.02800877]
# [ 0.07063248 -0.00883667 -0.1406254  -0.36139774]
# [ 0.07045574  0.1879748  -0.14785336 -0.69490846]
# [ 0.07421524  0.38480446 -0.16175153 -1.03024239]
# [ 0.08191133  0.19216084 -0.18235637 -0.79239676]
# [ 8.57545467e-02 -5.20085767e-05 -1.98204309e-01 -5.62174215e-01]
# Episode finished after 17 timesteps
# [ 0.04591429 -0.02926865 -0.04547152 -0.04200136]
# [ 0.04532892  0.16647486 -0.04631155 -0.34867715]
# [ 0.04865841  0.36222385 -0.05328509 -0.65559654]
# [ 0.05590289  0.55804556 -0.06639702 -0.96457062]
# [ 0.0670638   0.36387536 -0.08568843 -0.69346348]
# [ 0.07434131  0.5600749  -0.0995577  -1.01184458]
# [ 0.08554281  0.75637406 -0.11979459 -1.33405691]
# [ 0.10067029  0.56294839 -0.14647573 -1.0811332 ]
# [ 0.11192926  0.37003146 -0.1680984  -0.83776659]
# [ 0.11932989  0.17755479 -0.18485373 -0.60230962]
# [ 0.12288098 -0.0145662  -0.19689992 -0.37307584]
# [ 0.12258966  0.1827281  -0.20436144 -0.7208143 ]
# Episode finished after 12 timesteps
# [-0.02603701 -0.04329465  0.0417965  -0.01570591]
# [-0.02690291 -0.23899031  0.04148238  0.28986582]
# [-0.03168271 -0.04448367  0.0472797   0.01054918]
# [-0.03257239  0.14992946  0.04749068 -0.26684959]
# [-0.0295738   0.34434258  0.04215369 -0.54418347]
# [-0.02268695  0.53884761  0.03127002 -0.82329231]
# [-0.01190999  0.73352814  0.01480418 -1.10597847]
# [ 0.00276057  0.92845235 -0.00731539 -1.39398047]
# [ 0.02132962  1.12366458 -0.035195   -1.68894169]
# [ 0.04380291  1.31917522 -0.06897384 -1.99237123]
# [ 0.07018641  1.51494828 -0.10882126 -2.3055948 ]
# [ 0.10048538  1.32097886 -0.15493316 -2.04829206]
# [ 0.12690496  1.51731366 -0.195899   -2.384635  ]
# Episode finished after 13 timesteps

# %%
# save state
import dill

dill.dump_session("notebook_env.db")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-f42a4f2cb32d> in <module>
#       2 import dill
#       3
# ----> 4 dill.dump_session("notebook_env.db")
#
# /opt/python/anaconda3-2019-03/envs/mavan/lib/python3.7/site-packages/dill/_dill.py in dump_session(filename, main, byref, **kwds)
#     349         pickler._recurse = False # disable pickling recursion for globals
#     350         pickler._session = True  # is best indicator of when pickling a session
# --> 351         pickler.dump(main)
#     352     finally:
#     353         if f is not filename:  # If newly opened file
#
# /opt/python/anaconda3-2019-03/envs/mavan/lib/python3.7/site-packages/dill/_dill.py in dump(self, obj)
#     443             raise PicklingError(msg)
#     444         else:
# --> 445             StockPickler.dump(self, obj)
#     446         stack.clear()  # clear record of 'recursion-sensitive' pickled objects
#     447         return
#
# /opt/python/anaconda3-2019-03/envs/mavan/lib/python3.7/pickle.py in dump(self, obj)
#     435         if self.proto >= 4:
#     436             self.framer.start_framing()
# --> 437         self.save(obj)
#     438         self.write(STOP)
#     439         self.framer.end_framing()
#
# /opt/python/anaconda3-2019-03/envs/mavan/lib/python3.7/pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# /opt/python/anaconda3-2019-03/envs/mavan/lib/python3.7/site-packages/dill/_dill.py in save_module(pickler, obj)
#    1293                 + ["__builtins__", "__loader__"]]
#    1294             pickler.save_reduce(_import_module, (obj.__name__,), obj=obj,
# -> 1295                                 state=_main_dict)
#    1296             log.info("# M1")
#    1297         else:
#
# /opt/python/anaconda3-2019-03/envs/mavan/lib/python3.7/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     660
#     661         if state is not None:
# --> 662             save(state)
#     663             write(BUILD)
#     664
#
# /opt/python/anaconda3-2019-03/envs/mavan/lib/python3.7/pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# /opt/python/anaconda3-2019-03/envs/mavan/lib/python3.7/site-packages/dill/_dill.py in save_module_dict(pickler, obj)
#     910             # we only care about session the first pass thru
#     911             pickler._session = False
# --> 912         StockPickler.save_dict(pickler, obj)
#     913         log.info("# D2")
#     914     return
#
# /opt/python/anaconda3-2019-03/envs/mavan/lib/python3.7/pickle.py in save_dict(self, obj)
#     857
#     858         self.memoize(obj)
# --> 859         self._batch_setitems(obj.items())
#     860
#     861     dispatch[dict] = save_dict
#
# /opt/python/anaconda3-2019-03/envs/mavan/lib/python3.7/pickle.py in _batch_setitems(self, items)
#     883                 for k, v in tmp:
#     884                     save(k)
# --> 885                     save(v)
#     886                 write(SETITEMS)
#     887             elif n:
#
# /opt/python/anaconda3-2019-03/envs/mavan/lib/python3.7/pickle.py in save(self, obj, save_persistent_id)
#     502         f = self.dispatch.get(t)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#     506
#
# /opt/python/anaconda3-2019-03/envs/mavan/lib/python3.7/site-packages/dill/_dill.py in save_module(pickler, obj)
#    1282                      "prefix", "real_prefix"]
#    1283             builtin_mod = any([obj.__file__.startswith(os.path.normpath(getattr(sys, name)))
# -> 1284                            for name in names if hasattr(sys, name)])
#    1285             builtin_mod = builtin_mod or 'site-packages' in obj.__file__
#    1286         else:
#
# /opt/python/anaconda3-2019-03/envs/mavan/lib/python3.7/site-packages/dill/_dill.py in <listcomp>(.0)
#    1282                      "prefix", "real_prefix"]
#    1283             builtin_mod = any([obj.__file__.startswith(os.path.normpath(getattr(sys, name)))
# -> 1284                            for name in names if hasattr(sys, name)])
#    1285             builtin_mod = builtin_mod or 'site-packages' in obj.__file__
#    1286         else:
#
# AttributeError: 'NoneType' object has no attribute 'startswith'
